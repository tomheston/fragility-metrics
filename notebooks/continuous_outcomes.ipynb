# %% [markdown]
# <a href="https://colab.research.google.com/github/tomheston/fragility-metrics/blob/main/notebooks/continuous_outcomes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title
# Fragility Metrics Toolkit: Continuous Outcomes (Welch t-test)
# 20-NOV-2025
# Fully aligned with FRAGILITY_METRICS.md v9.5 §3.7 CFQ/CFS and §4 MeCI
#
# Input: m1, sd1, n1  (group 1), m2, sd2, n2  (group 2)
# Output: p (Welch t p-value), fr (CFS/CFQ), nb (MeCI)
#
# Formulas (exact v9.5):
# - CFS  = ||T| – t*|   (SE-unit distance to the α=0.05 boundary)
# - CFQ  = CFS / (1 + CFS)                  → fragility quotient 0–1
# - MeCI = D / (1 + D)   where D = |m1-m2| / SE_diff   → robustness 0–1
#
# IF YOU USE THIS CALCULATOR PLEASE CITE:
# Heston, T. F. (2025). Fragility Metrics Toolkit [Software]. Zenodo. https://doi.org/10.5281/zenodo.17254763
#
# © Thomas F. Heston 2025. CC-BY 4.0

import numpy as np
from scipy.stats import t

ALPHA = 0.05

# ---------- Core calculations ----------
def welch_t_test(m1, sd1, n1, m2, sd2, n2):
    se1 = sd1 / np.sqrt(n1)
    se2 = sd2 / np.sqrt(n2)
    se_diff = np.sqrt(se1**2 + se2**2)
    t_stat = (m1 - m2) / se_diff
    df = (se1**2 + se2**2)**2 / (se1**4 / (n1 - 1) + se2**4 / (n2 - 1))
    p_val = 2 * t.sf(np.abs(t_stat), df)
    return t_stat, p_val, se_diff, df

def compute_cfs_cfq(t_stat, df, alpha=ALPHA):
    t_crit = t.ppf(1 - alpha/2, df)
    cfs = abs(t_stat) - t_crit
    cfq = cfs / (1 + cfs) if cfs >= 0 else 0.0   # CFS can be negative only if already nonsig → fragility=0
    return cfs, cfq

def compute_meci(m1, m2, se_diff):
    d = abs(m1 - m2) / se_diff
    return d / (1 + d)

# ---------- High-level ----------
def continuous_outcomes(m1, sd1, n1, m2, sd2, n2):
    if n1 < 2 or n2 < 2:
        raise ValueError("Sample sizes must be ≥2")
    if sd1 <= 0 or sd2 <= 0:
        raise ValueError("Standard deviations must be positive")

    t_stat, p_val, se_diff, df = welch_t_test(m1, sd1, n1, m2, sd2, n2)
    cfs, cfq = compute_cfs_cfq(t_stat, df)
    meci = compute_meci(m1, m2, se_diff)

    return {
        "m1": m1, "sd1": sd1, "n1": n1,
        "m2": m2, "sd2": sd2, "n2": n2,
        "t_stat": t_stat,
        "df": df,
        "p": p_val,
        "fr": {"CFS": cfs, "CFQ": cfq},
        "nb": {"MeCI": meci}
    }

# ---------- Narrative ----------
def generate_narrative(res):
    diff = abs(res["m1"] - res["m2"])
    se = (res["sd1"]**2 / res["n1"] + res["sd2"]**2 / res["n2"])**0.5

    lines = [
        f"Group 1: mean = {res['m1']:.4f}, sd = {res['sd1']:.4f}, n = {res['n1']}",
        f"Group 2: mean = {res['m2']:.4f}, sd = {res['sd2']:.4f}, n = {res['n2']}",
        f"Mean difference = {diff:.4f} (SE = {se:.4f})",
        f"Welch t = {res['t_stat']:.4f}, df ≈ {res['df']:.1f}, p = {res['p']:.6f}",
    ]

    # Fragility
    if res["fr"]["CFS"] <= 0:
        frag = "The result is already non-significant – fragility = 0 (CFQ = 0.000000)"
    else:
        stability = (
            "extremely fragile" if res["fr"]["CFQ"] < 0.01 else
            "very fragile" if res["fr"]["CFQ"] < 0.05 else
            "fragile" if res["fr"]["CFQ"] < 0.10 else
            "moderately stable" if res["fr"]["CFQ"] < 0.25 else
            "very stable"
        )
        frag = f"CFS = {res['fr']['CFS']:.4f} SE units to boundary → CFQ = {res['fr']['CFQ']:.6f} ({stability})"

    # Robustness
    separation = (
        "at neutrality boundary" if res["nb"]["MeCI"] < 0.05 else
        "near neutrality" if res["nb"]["MeCI"] < 0.10 else
        "moderately separated" if res["nb"]["MeCI"] < 0.25 else
        "clearly separated" if res["nb"]["MeCI"] < 0.50 else
        "far from neutrality"
    )
    rob = f"MeCI = {res['nb']['MeCI']:.6f} → {separation}"

    lines += ["", frag, rob, ""]
    if res["p"] <= ALPHA:
        lines.append("Claim of difference is currently supported and is " +
                     ("highly stable and robust." if res["fr"]["CFQ"] > 0.25 and res["nb"]["MeCI"] > 0.5 else
                      "fragile and/or close to neutrality."))
    else:
        lines.append("Claim of difference is currently NOT supported.")
    return "\n".join(lines)

# ---------- CLI ----------
def main():
    print("Continuous Outcomes Calculator (Welch t) – v9.5 compliant\n")
    print("Group 1")
    m1 = float(input("Mean: "))
    sd1 = float(input("SD: "))
    n1 = int(input("n: "))
    print("Group 2")
    m2 = float(input("Mean: "))
    sd2 = float(input("SD: "))
    n2 = int(input("n: "))

    res = continuous_outcomes(m1, sd1, n1, m2, sd2, n2)

    print("\n================ p–fr–nb ================")
    print(f"p (Welch t) = {res['p']:.6f}")
    print(f"CFS = {res['fr']['CFS']:.4f}")
    print(f"CFQ = {res['fr']['CFQ']:.6f}")
    print(f"MeCI = {res['nb']['MeCI']:.6f}")
    print("=========================================\n")

    print("Interpretation:")
    print(generate_narrative(res))

if __name__ == "__main__":
    main()
# Out:
# Downloading RCW_Title_01.pdf ...
# Failed to download RCW_Title_01.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_01.pdf
# Downloading RCW_Title_02.pdf ...
# Failed to download RCW_Title_02.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_02.pdf
# Downloading RCW_Title_03.pdf ...
# Failed to download RCW_Title_03.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_03.pdf
# Downloading RCW_Title_04.pdf ...
# Failed to download RCW_Title_04.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_04.pdf
# Downloading RCW_Title_05.pdf ...
# Failed to download RCW_Title_05.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_05.pdf
# Downloading RCW_Title_06.pdf ...
# Failed to download RCW_Title_06.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_06.pdf
# Downloading RCW_Title_07.pdf ...
# Failed to download RCW_Title_07.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_07.pdf
# Downloading RCW_Title_08.pdf ...
# Failed to download RCW_Title_08.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_08.pdf
# Downloading RCW_Title_09.pdf ...
# Failed to download RCW_Title_09.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_09.pdf
# Downloading RCW_Title_10.pdf ...
# Failed to download RCW_Title_10.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_10.pdf
# Downloading RCW_Title_11.pdf ...
# Failed to download RCW_Title_11.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_11.pdf
# Downloading RCW_Title_12.pdf ...
# Failed to download RCW_Title_12.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_12.pdf
# Downloading RCW_Title_13.pdf ...
# Failed to download RCW_Title_13.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_13.pdf
# Downloading RCW_Title_14.pdf ...
# Failed to download RCW_Title_14.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_14.pdf
# Downloading RCW_Title_15.pdf ...
# Failed to download RCW_Title_15.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_15.pdf
# Downloading RCW_Title_16.pdf ...
# Failed to download RCW_Title_16.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_16.pdf
# Downloading RCW_Title_17.pdf ...
# Failed to download RCW_Title_17.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_17.pdf
# Downloading RCW_Title_18.pdf ...
# Failed to download RCW_Title_18.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_18.pdf
# Downloading RCW_Title_19.pdf ...
# Failed to download RCW_Title_19.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_19.pdf
# Downloading RCW_Title_20.pdf ...
# Failed to download RCW_Title_20.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_20.pdf
# Downloading RCW_Title_21.pdf ...
# Failed to download RCW_Title_21.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_21.pdf
# Downloading RCW_Title_22.pdf ...
# Failed to download RCW_Title_22.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_22.pdf
# Downloading RCW_Title_23.pdf ...
# Failed to download RCW_Title_23.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_23.pdf
# Downloading RCW_Title_24.pdf ...
# Failed to download RCW_Title_24.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_24.pdf
# Downloading RCW_Title_25.pdf ...
# Failed to download RCW_Title_25.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_25.pdf
# Downloading RCW_Title_26.pdf ...
# Failed to download RCW_Title_26.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_26.pdf
# Downloading RCW_Title_27.pdf ...
# Failed to download RCW_Title_27.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_27.pdf
# Downloading RCW_Title_28.pdf ...
# Failed to download RCW_Title_28.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_28.pdf
# Downloading RCW_Title_29.pdf ...
# Failed to download RCW_Title_29.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_29.pdf
# Downloading RCW_Title_30.pdf ...
# Failed to download RCW_Title_30.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_30.pdf
# Downloading RCW_Title_31.pdf ...
# Failed to download RCW_Title_31.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_31.pdf
# Downloading RCW_Title_32.pdf ...
# Failed to download RCW_Title_32.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_32.pdf
# Downloading RCW_Title_33.pdf ...
# Failed to download RCW_Title_33.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_33.pdf
# Downloading RCW_Title_34.pdf ...
# Failed to download RCW_Title_34.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_34.pdf
# Downloading RCW_Title_35.pdf ...
# Failed to download RCW_Title_35.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_35.pdf
# Downloading RCW_Title_36.pdf ...
# Failed to download RCW_Title_36.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_36.pdf
# Downloading RCW_Title_37.pdf ...
# Failed to download RCW_Title_37.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_37.pdf
# Downloading RCW_Title_38.pdf ...
# Failed to download RCW_Title_38.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_38.pdf
# Downloading RCW_Title_39.pdf ...
# Failed to download RCW_Title_39.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_39.pdf
# Downloading RCW_Title_40.pdf ...
# Failed to download RCW_Title_40.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_40.pdf
# Downloading RCW_Title_41.pdf ...
# Failed to download RCW_Title_41.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_41.pdf
# Downloading RCW_Title_42.pdf ...
# Failed to download RCW_Title_42.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_42.pdf
# Downloading RCW_Title_43.pdf ...
# Failed to download RCW_Title_43.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_43.pdf
# Downloading RCW_Title_44.pdf ...
# Failed to download RCW_Title_44.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_44.pdf
# Downloading RCW_Title_45.pdf ...
# Failed to download RCW_Title_45.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_45.pdf
# Downloading RCW_Title_46.pdf ...
# Failed to download RCW_Title_46.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_46.pdf
# Downloading RCW_Title_47.pdf ...
# Failed to download RCW_Title_47.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_47.pdf
# Downloading RCW_Title_48.pdf ...
# Failed to download RCW_Title_48.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_48.pdf
# Downloading RCW_Title_49.pdf ...
# Failed to download RCW_Title_49.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_49.pdf
# Downloading RCW_Title_50.pdf ...
# Failed to download RCW_Title_50.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_50.pdf
# Downloading RCW_Title_51.pdf ...
# Failed to download RCW_Title_51.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_51.pdf
# Downloading RCW_Title_52.pdf ...
# Failed to download RCW_Title_52.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_52.pdf
# Downloading RCW_Title_53.pdf ...
# Failed to download RCW_Title_53.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_53.pdf
# Downloading RCW_Title_54.pdf ...
# Failed to download RCW_Title_54.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_54.pdf
# Downloading RCW_Title_55.pdf ...
# Failed to download RCW_Title_55.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_55.pdf
# Downloading RCW_Title_56.pdf ...
# Failed to download RCW_Title_56.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_56.pdf
# Downloading RCW_Title_57.pdf ...
# Failed to download RCW_Title_57.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_57.pdf
# Downloading RCW_Title_58.pdf ...
# Failed to download RCW_Title_58.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_58.pdf
# Downloading RCW_Title_59.pdf ...
# Failed to download RCW_Title_59.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_59.pdf
# Downloading RCW_Title_60.pdf ...
# Failed to download RCW_Title_60.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_60.pdf
# Downloading RCW_Title_61.pdf ...
# Failed to download RCW_Title_61.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_61.pdf
# Downloading RCW_Title_62.pdf ...
# Failed to download RCW_Title_62.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_62.pdf
# Downloading RCW_Title_63.pdf ...
# Failed to download RCW_Title_63.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_63.pdf
# Downloading RCW_Title_64.pdf ...
# Failed to download RCW_Title_64.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_64.pdf
# Downloading RCW_Title_65.pdf ...
# Failed to download RCW_Title_65.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_65.pdf
# Downloading RCW_Title_66.pdf ...
# Failed to download RCW_Title_66.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_66.pdf
# Downloading RCW_Title_67.pdf ...
# Failed to download RCW_Title_67.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_67.pdf
# Downloading RCW_Title_68.pdf ...
# Failed to download RCW_Title_68.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_68.pdf
# Downloading RCW_Title_69.pdf ...
# Failed to download RCW_Title_69.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_69.pdf
# Downloading RCW_Title_70.pdf ...
# Failed to download RCW_Title_70.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_70.pdf
# Downloading RCW_Title_71.pdf ...
# Failed to download RCW_Title_71.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_71.pdf
# Downloading RCW_Title_72.pdf ...
# Failed to download RCW_Title_72.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_72.pdf
# Downloading RCW_Title_73.pdf ...
# Failed to download RCW_Title_73.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_73.pdf
# Downloading RCW_Title_74.pdf ...
# Failed to download RCW_Title_74.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_74.pdf
# Downloading RCW_Title_75.pdf ...
# Failed to download RCW_Title_75.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_75.pdf
# Downloading RCW_Title_76.pdf ...
# Failed to download RCW_Title_76.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_76.pdf
# Downloading RCW_Title_77.pdf ...
# Failed to download RCW_Title_77.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_77.pdf
# Downloading RCW_Title_78.pdf ...
# Failed to download RCW_Title_78.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_78.pdf
# Downloading RCW_Title_79.pdf ...
# Failed to download RCW_Title_79.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_79.pdf
# Downloading RCW_Title_80.pdf ...
# Failed to download RCW_Title_80.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_80.pdf
# Downloading RCW_Title_81.pdf ...
# Failed to download RCW_Title_81.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_81.pdf
# Downloading RCW_Title_82.pdf ...
# Failed to download RCW_Title_82.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_82.pdf
# Downloading RCW_Title_83.pdf ...
# Failed to download RCW_Title_83.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_83.pdf
# Downloading RCW_Title_84.pdf ...
# Failed to download RCW_Title_84.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_84.pdf
# Downloading RCW_Title_85.pdf ...
# Failed to download RCW_Title_85.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_85.pdf
# Downloading RCW_Title_86.pdf ...
# Failed to download RCW_Title_86.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_86.pdf
# Downloading RCW_Title_87.pdf ...
# Failed to download RCW_Title_87.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_87.pdf
# Downloading RCW_Title_88.pdf ...
# Failed to download RCW_Title_88.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_88.pdf
# Downloading RCW_Title_89.pdf ...
# Failed to download RCW_Title_89.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_89.pdf
# Downloading RCW_Title_90.pdf ...
# Failed to download RCW_Title_90.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_90.pdf
# Downloading RCW_Title_91.pdf ...
# Failed to download RCW_Title_91.pdf: 404 Client Error: Not Found for url: https://leg.wa.gov/CodeReviser/documents/rcw/RCW_Title_91.pdf
