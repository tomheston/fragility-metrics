# %% [markdown]
# <a href="https://colab.research.google.com/github/tomheston/fragility-metrics/blob/main/notebooks/continuous_outcomes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title
# Fragility Metrics Toolkit: Continuous Outcomes (Welch t-test)
# 22-NOV-2025
# Fully aligned with FRAGILITY_METRICS.md v9.6 §3.7 CFQ/CFS and §4.3 MeCI
#
# Two modes:
#   MODE 1: Full data (m1, sd1, n1, m2, sd2, n2)
#   MODE 2: CI-only (mean difference + 95% CI bounds)
#
# Output: p (Welch t p-value), fr (CFS/CFQ), nb (MeCI)
#
# Formulas (exact v9.6):
# - CFS  = ||T| – t*|  → always positive distance to α=0.05 boundary
# - CFQ  = CFS / (1 + CFS)
# - MeCI = |T| / (1 + |T|) where T is the Welch t-statistic
#
# Note: MODE 1 requires standard deviations (SD), not standard errors (SE).
# Most papers report mean ± SE. Convert using: SD = SE × √n
#
# IF YOU USE THIS CALCULATOR PLEASE CITE:
# Heston, T. F. (2025). Fragility Metrics Toolkit [Software]. Zenodo. https://doi.org/10.5281/zenodo.17254763
#
# © Thomas F. Heston 2025. CC-BY 4.0

import numpy as np
from scipy.stats import t

ALPHA = 0.05

# ==================== MODE 1: Full data (m1, sd1, n1, m2, sd2, n2) ====================
def full_data_mode(m1, sd1, n1, m2, sd2, n2):
    """
    Calculate p-fr-nb from complete group statistics.
    Requires: means, standard deviations, and sample sizes for both groups.
    """
    if n1 < 2 or n2 < 2 or sd1 <= 0 or sd2 <= 0:
        raise ValueError("Invalid input: n ≥ 2 and SD > 0 required")

    # Welch t-test
    se1 = sd1 / np.sqrt(n1)
    se2 = sd2 / np.sqrt(n2)
    se_diff = np.sqrt(se1**2 + se2**2)
    t_stat = (m1 - m2) / se_diff
    df = (se1**2 + se2**2)**2 / (se1**4 / (n1-1) + se2**4 / (n2-1))
    p_val = 2 * t.sf(np.abs(t_stat), df)
    t_crit = t.ppf(1 - ALPHA/2, df)

    # CFQ / CFS — symmetric distance to boundary
    cfs = abs(abs(t_stat) - t_crit)
    cfq = cfs / (1 + cfs)

    # MeCI — exact v9.6 Neutrality Boundary Framework
    meci = abs(t_stat) / (1 + abs(t_stat))

    return {
        "p": p_val,
        "CFS": cfs,
        "CFQ": cfq,
        "MeCI": meci,
        "T": t_stat,
        "df": df,
        "se_diff": se_diff,
        "mean_diff": abs(m1 - m2)
    }

# ==================== MODE 2: CI-only (mean difference + 95% CI) ====================
def ci_only_mode(delta, ci_lower, ci_upper):
    """
    Calculate approximate p-fr-nb from mean difference and 95% CI only.
    Uses large-sample z-approximation (t* ≈ 1.96).
    """
    # Extract SE from CI width
    se_diff = (ci_upper - ci_lower) / 3.92  # 95% CI width ÷ (2 × 1.96)

    # Approximate T-statistic
    T_approx = abs(delta) / se_diff
    t_crit = 1.96  # large-sample approximation

    # CFS (corrected with nested absolute value)
    cfs = abs(abs(T_approx) - t_crit)
    cfq = cfs / (1 + cfs)

    # MeCI
    meci = T_approx / (1 + T_approx)

    # Approximate p-value
    p_approx = 2 * (1 - t.cdf(T_approx, df=999))

    return {
        "p": p_approx,
        "CFS": cfs,
        "CFQ": cfq,
        "MeCI": meci,
        "T": T_approx,
        "se_diff": se_diff,
        "mean_diff": abs(delta)
    }

# ==================== Output formatter ====================
def print_results(results, mode="full"):
    """Pretty-print p-fr-nb results"""
    print("\n" + "="*60)
    print(f"{'FULL DATA MODE' if mode=='full' else 'CI-ONLY MODE (APPROXIMATE)'}")
    print("="*60)
    print(f"Mean difference = {results['mean_diff']:.4f}")
    print(f"SE_diff = {results['se_diff']:.4f}")
    print(f"|T| = {abs(results['T']):.3f}")
    if mode == "full":
        print(f"df = {results['df']:.1f}")
    print()
    print(f"p-value = {results['p']:.6f}  →  {'significant' if results['p']<=ALPHA else 'not significant'}")
    print(f"fr: CFQ = {results['CFQ']:.6f}  (CFS = {results['CFS']:.3f} SE-units to boundary)")
    print(f"nb: MeCI = {results['MeCI']:.6f}")
    print("="*60 + "\n")

# ==================== Example usage ====================
if __name__ == "__main__":
    print("Continuous Outcomes Calculator – FRAGILITY_METRICS v9.6\n")

    # Example 1: Full data mode
    print("EXAMPLE 1: Full data (means, SDs, sample sizes: m1 m2 s1 s2 n1 n2)")
    res1 = full_data_mode(m1=15.6, sd1=7.238, n1=31, m2=8.1, sd2=6.573, n2=30)
    print_results(res1, mode="full")

    # Example 2: CI-only mode
    print("EXAMPLE 2: CI-only mode (mean difference + 95% CI)")
    res2 = ci_only_mode(delta=1.19, ci_lower=0.13, ci_upper=2.25)
    print_results(res2, mode="ci")

    # Interactive mode
    print("\n" + "="*60)
    print("For interactive use, uncomment the section below:")
    print("="*60)

    # Uncomment for interactive input:

    mode = input("Choose mode (1=full data, 2=CI only): ")

    if mode == "1":
        print("\nFull data mode - enter group statistics:")
        m1 = float(input("Group 1 mean: "))
        sd1 = float(input("Group 1 SD: "))
        n1 = int(input("Group 1 n: "))
        m2 = float(input("Group 2 mean: "))
        sd2 = float(input("Group 2 SD: "))
        n2 = int(input("Group 2 n: "))

        results = full_data_mode(m1, sd1, n1, m2, sd2, n2)
        print_results(results, mode="full")

    else:
        print("\nCI-only mode - enter mean difference and 95% CI:")
        delta = float(input("Mean difference: "))
        ci_lower = float(input("95% CI lower bound: "))
        ci_upper = float(input("95% CI upper bound: "))

        results = ci_only_mode(delta, ci_lower, ci_upper)
        print_results(results, mode="ci")
# Out:
# Continuous Outcomes Calculator – FRAGILITY_METRICS v9.6
#
# EXAMPLE 1: Full data (means, SDs, sample sizes: m1 m2 s1 s2 n1 n2)
#
# ============================================================
# FULL DATA MODE
# ============================================================
# Mean difference = 7.5000
# SE_diff = 1.7692
# |T| = 4.239
# df = 58.8
#
# p-value = 0.000080  →  significant
# fr: CFQ = 0.691169  (CFS = 2.238 SE-units to boundary)
# nb: MeCI = 0.809131
# ============================================================
#
# EXAMPLE 2: CI-only mode (mean difference + 95% CI)
#
# ============================================================
# CI-ONLY MODE (APPROXIMATE)
# ============================================================
# Mean difference = 1.1900
# SE_diff = 0.5408
# |T| = 2.200
#
# p-value = 0.028008  →  significant
# fr: CFQ = 0.193794  (CFS = 0.240 SE-units to boundary)
# nb: MeCI = 0.687537
# ============================================================
#
#
# ============================================================
# For interactive use, uncomment the section below:
# ============================================================
