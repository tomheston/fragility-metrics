# %% [markdown]
# <a href="https://colab.research.google.com/github/tomheston/fragility-metrics/blob/main/notebooks/binary_2x2_fixed_margin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title
# Fragility Metrics Toolkit: Matched / Fixed-Margin Binary Outcomes (2×2)
# 21-NOV-2025
#
# Layout (generic 2×2 fixed-margin / matched design):
#      | Outcome A | Outcome B |
# ArmA |     a     |    b      |
# ArmB |     c     |    d      |
#
# Input:
#   a, b, c, d  (non-negative integers; margins fixed by design)
#
# Output (p–fr–nb):
#   p   : McNemar χ² baseline p-value (two-sided, uncorrected)
#   fr  : PFI (Percent Fragility Index, decimal scale) via McNemar path
#   nb  : MHQ (distance from marginal homogeneity)
#
# Notes
# - This calculator is for matched / fixed-margin 2×2 designs.
# - Baseline significance test: McNemar χ² (two-sided, df = 1, no correction).
# - PFI is computed along the fixed-margin path:
#       (a, b, c, d) → (a + x, b - x, c - x, d + x)
#   with continuous x. Along this path, McNemar p-value is strictly monotonic:
#   p(x) decreases as x increases.
#   Normalization: 4 × |x| / N, clamped to [0,1].
#
#   In extreme-margin cases, PFI = 1 can correspond either to a true boundary-limited configuration
#   or to an interior root where 4·|x*|/N > 1 on the nominal scale; the clamping
#   hides the difference. The boundary_limited flag is the disambiguator.
#
# IF YOU USE THIS CALCULATOR PLEASE CITE:
# Heston, T. F. (2025). Fragility Metrics Toolkit [Software]. Zenodo.
# https://doi.org/10.5281/zenodo.17254763
#
# © Thomas F. Heston 2025. CC-BY 4.0

# ----- SciPy availability guard -----
try:
    import scipy
except ImportError:
    try:
        import subprocess
        import sys
        subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "scipy"])
        import scipy
    except Exception:
        print("Please install scipy: pip install scipy")
        raise

import numpy as np
from scipy.stats import chi2

ALPHA = 0.05


# ---------- Core utilities ----------

def n_total(a, b, c, d):
    """Total sample size."""
    return a + b + c + d


def mcnemar_p(a, b, c, d):
    """
    McNemar χ² test (two-sided, uncorrected).
    χ² = (b - c)² / (b + c), df = 1, no continuity correction.
    """
    b_c = b + c
    if b_c == 0:
        # no discordant pairs → cannot reject marginal homogeneity
        return 1.0
    chi2_stat = (b - c) ** 2 / b_c
    p = chi2.sf(chi2_stat, df=1)
    return float(p)


def p_along_x_mcnemar(a, b, c, d, x):
    """
    McNemar p-value along the fixed-margin path:
    (a, b, c, d) → (a + x, b - x, c - x, d + x)
    """
    aa, bb, cc, dd = a + x, b - x, c - x, d + x
    if min(aa, bb, cc, dd) < 0:
        return np.nan
    return mcnemar_p(aa, bb, cc, dd)


# ---------- PFI + MHQ (fixed-margin, McNemar path) ----------

def compute_pfi_and_mhq(a, b, c, d, alpha=ALPHA, tol=1e-12, max_iter=300):
    """
    Compute:
      - PFI (Percent Fragility Index, decimal scale) via McNemar path
      - MHQ = |b - c| / (b + c): distance from marginal homogeneity

    Returns dict with keys:
      "PFI"             : float in [0,1]
      "MHQ"             : float in [0,1]
      "boundary_limited": bool
    """
    a, b, c, d = map(float, (a, b, c, d))
    n = a + b + c + d
    if n <= 0 or min(a, b, c, d) < 0:
        return {"PFI": 0.0, "MHQ": 0.0, "boundary_limited": False}

    # Robustness (nb) – distance from marginal homogeneity (McNemar null)
    discordants = b + c
    if discordants == 0:
        # perfect diagonal: maximal stability of neutrality
        mhq = 0.0
        return {"PFI": 1.0, "MHQ": mhq, "boundary_limited": True}

    mhq = abs(b - c) / discordants  # in [0,1]

    # Feasible shift range for x
    x_min = -min(a, d)
    x_max = min(b, c)

    # Baseline p-value
    p0 = mcnemar_p(a, b, c, d)
    if not np.isfinite(p0):
        return {"PFI": 0.0, "MHQ": mhq, "boundary_limited": False}

    sig0 = (p0 <= alpha)

    def f(x):
        return p_along_x_mcnemar(a, b, c, d, x) - alpha

    # Monotonicity: p(x) decreases as x increases
    if sig0:
        # significant: move toward x_min (less extreme) to lose significance
        lo, hi = x_min, 0.0
        boundary_x = x_min
    else:
        # non-significant: move toward x_max (more extreme) to gain significance
        lo, hi = 0.0, x_max
        boundary_x = x_max

    # Degenerate interval: treat as boundary-limited
    if abs(lo - hi) < tol:
        pfi_raw = 4.0 * abs(boundary_x) / n
        pfi = max(0.0, min(1.0, pfi_raw))
        return {"PFI": pfi, "MHQ": mhq, "boundary_limited": True}

    flo, fhi = f(lo), f(hi)

    # If we can't bracket a root cleanly, treat as boundary-limited
    if not (np.isfinite(flo) and np.isfinite(fhi)) or flo * fhi > 0:
        pfi_raw = 4.0 * abs(boundary_x) / n
        pfi = max(0.0, min(1.0, pfi_raw))
        return {"PFI": pfi, "MHQ": mhq, "boundary_limited": True}

    # Bisection (normal case)
    x_star = None
    for _ in range(max_iter):
        mid = 0.5 * (lo + hi)
        fmid = f(mid)
        if not np.isfinite(fmid):
            mid = np.nextafter(mid, hi)
            fmid = f(mid)
            if not np.isfinite(fmid):
                break
        if abs(hi - lo) < tol or fmid == 0:
            x_star = mid
            break
        if flo * fmid <= 0:
            hi, fhi = mid, fmid
        else:
            lo, flo = mid, fmid

    if x_star is None:
        # Fallback: midpoint of current interval
        x_star = 0.5 * (lo + hi)

    pfi_raw = 4.0 * abs(x_star) / n
    # Enforce [0,1] range
    pfi = max(0.0, min(1.0, pfi_raw))
    # Boundary-limited if the root is effectively at the boundary
    boundary_limited = (abs(abs(x_star) - abs(boundary_x)) < tol)

    return {"PFI": pfi, "MHQ": mhq, "boundary_limited": boundary_limited}


# ---------- High-level calculator ----------

def calculate_binary_2x2_fixed_margin(a, b, c, d, alpha=ALPHA):
    p_val = mcnemar_p(a, b, c, d)
    result = compute_pfi_and_mhq(a, b, c, d, alpha=alpha)
    return {
        "p": p_val,
        "fr": {
            "PFI": result["PFI"],
            "boundary_limited": result["boundary_limited"],
        },
        "nb": {
            "MHQ": result["MHQ"]
        }
    }


# ---------- CLI ----------

def main():
    print("Enter 2×2 fixed-margin table cells as integers.")
    a = int(input("a (Arm A outcome A): ").strip())
    b = int(input("b (Arm A outcome B): ").strip())
    c = int(input("c (Arm B outcome A): ").strip())
    d = int(input("d (Arm B outcome B): ").strip())

    res = calculate_binary_2x2_fixed_margin(a, b, c, d)
    N = n_total(a, b, c, d)

    print("\n================ p–fr–nb =================")
    print(f"N = {N}")
    print(f"p = {res['p']:.5f} (McNemar χ² two-sided)")

    pfi_val = res["fr"]["PFI"]
    note = (
        " (boundary-limited: no admissible shift flips significance)"
        if res["fr"]["boundary_limited"]
        else " (PFI)"
    )
    print(f"fr = {pfi_val:.6f}{note}")

    mhq_val = res["nb"]["MHQ"]
    print(f"nb = {mhq_val:.6f} (MHQ)")

    print("==========================================")

if __name__ == "__main__":
    main()
# Out:
# Enter 2×2 fixed-margin table cells as integers.
# a (Arm A outcome A): 310
# b (Arm A outcome B): 2273
# c (Arm B outcome A): 92
# d (Arm B outcome B): 2730
#
# ================ p–fr–nb =================
# N = 5405
# p = 0.00000 (McNemar χ² two-sided)
# fr = 0.229417 (boundary-limited: no admissible shift flips significance)
# nb = 0.922199 (MHQ)
# ==========================================
